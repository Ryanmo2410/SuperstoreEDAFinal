# %% [markdown]
# # Superstore
# Ryan Morrissey

# %% [markdown]
# This is the superstore data set that contains their records for orders placed
#
# Dictionary
# df = superstore excel sheet 0
# df_people = superstore excel sheet 1
# df1 = superstore excel file
# path = shortcut to loading up superstore from google drive

# %%
import pandas as pd

# %%
# Display all dataframe columns
pd.set_option('display.max_columns', None)

# %%
# Import Google drive
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
# Defining df as excel file from Superstore
df = pd.read_excel('/content/drive/MyDrive/Descriptive Analytics/Superstore EDA/Data/Global_Superstore_Orders_2012_2015.xlsx')

# %%
df.head()
# Out:
#    Row ID                  Order ID Order Date  Ship Date       Ship Mode  \
# 0   42433    AG-2012-TB112803-40909 2012-01-01 2012-01-06  Standard Class
# 1   22253    IN-2012-JH159857-40909 2012-01-01 2012-01-08  Standard Class
# 2   48883     HU-2012-AT73557-40909 2012-01-01 2012-01-05    Second Class
# 3   11731  IT-2012-EM14140124-40909 2012-01-01 2012-01-05    Second Class
# 4   22255    IN-2012-JH159857-40909 2012-01-01 2012-01-08  Standard Class
#
#    Customer ID    Customer Name      Segment  Postal Code         City  \
# 0    TB-112803  Toby Braunhardt     Consumer          NaN  Constantine
# 1    JH-159857      Joseph Holt     Consumer          NaN  Wagga Wagga
# 2     AT-73557    Annie Thurman     Consumer          NaN     Budapest
# 3  EM-14140124     Eugene Moren  Home Office          NaN    Stockholm
# 4    JH-159857      Joseph Holt     Consumer          NaN  Wagga Wagga
#
#              State    Country           Region        Market   Product ID  \
# ...

# %%
df.shape
# Out:
# (51290, 24)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51290 entries, 0 to 51289
# Data columns (total 24 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Row ID          51290 non-null  int64
#  1   Order ID        51290 non-null  object
#  2   Order Date      51290 non-null  datetime64[ns]
#  3   Ship Date       51290 non-null  datetime64[ns]
#  4   Ship Mode       51290 non-null  object
#  5   Customer ID     51290 non-null  object
#  6   Customer Name   51290 non-null  object
#  7   Segment         51290 non-null  object
#  8   Postal Code     9994 non-null   float64
#  9   City            51290 non-null  object
#  10  State           51290 non-null  object
#  11  Country         51290 non-null  object
#  12  Region          51290 non-null  object
#  13  Market          51290 non-null  object
#  14  Product ID      51290 non-null  object
#  15  Category        51290 non-null  object
# ...

# %%
df.describe()
# Out:
#             Row ID                     Order Date  \
# count  51290.00000                          51290
# mean   25645.50000  2014-05-11 21:26:49.155780864
# min        1.00000            2012-01-01 00:00:00
# 25%    12823.25000            2013-06-19 00:00:00
# 50%    25645.50000            2014-07-08 00:00:00
# 75%    38467.75000            2015-05-22 00:00:00
# max    51290.00000            2015-12-31 00:00:00
# std    14806.29199                            NaN
#
#                            Ship Date   Postal Code         Sales  \
# count                          51290   9994.000000  51290.000000
# mean   2014-05-15 20:42:42.745174528  55190.379428    246.490581
# min              2012-01-03 00:00:00   1040.000000      0.444000
# 25%              2013-06-23 00:00:00  23223.000000     30.758625
# 50%              2014-07-12 00:00:00  56430.500000     85.053000
# 75%              2015-05-26 00:00:00  90008.000000    251.053200
# ...

# %% [markdown]
# ## Merge Files: Orders to People

# %%
# defining the new df_people from excel sheet 1 in superstore file
df_people = pd.read_excel('/content/drive/MyDrive/Descriptive Analytics/Superstore EDA/Data/Global_Superstore_Orders_2012_2015.xlsx', sheet_name=1)
df_people.head()
# Out:
#               Person           Region
# 0  Marilène Rousseau        Caribbean
# 1   Andile Ihejirika   Central Africa
# 2  Nicodemo Bautista  Central America
# 3     Cansu Peynirci     Central Asia
# 4         Lon Bonher       Central US

# %%
df_people.shape
# Out:
# (24, 2)

# %%
df_people.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24 entries, 0 to 23
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Person  24 non-null     object
#  1   Region  24 non-null     object
# dtypes: object(2)
# memory usage: 516.0+ bytes

# %%
# Merge df with df_people

df.sample(5)
# Out:
#        Row ID                  Order ID Order Date  Ship Date       Ship Mode  \
# 47545    1852   MX-2015-AJ1096051-42318 2015-11-10 2015-11-12    Second Class
# 21471    3283   MX-2014-KN1670531-41706 2014-03-08 2014-03-13  Standard Class
# 51018   35082  CA-2015-TC21535140-42365 2015-12-27 2015-12-31  Standard Class
# 49227   23069  ID-2015-KA16525102-42340 2015-12-02 2015-12-09  Standard Class
# 37601   34076  CA-2015-SS20140140-42125 2015-05-01 2015-05-06  Standard Class
#
#         Customer ID     Customer Name      Segment  Postal Code  \
# 47545    AJ-1096051      Astrea Jones     Consumer          NaN
# 21471    KN-1670531     Kristina Nunn  Home Office          NaN
# 51018  TC-215351406     Tracy Collins  Home Office      43229.0
# 49227   KA-16525102    Kelly Andreada     Consumer          NaN
# 37601  SS-201401408  Saphhira Shifley    Corporate      33068.0
#
#                 City             State        Country             Region  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51290 entries, 0 to 51289
# Data columns (total 24 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Row ID          51290 non-null  int64
#  1   Order ID        51290 non-null  object
#  2   Order Date      51290 non-null  datetime64[ns]
#  3   Ship Date       51290 non-null  datetime64[ns]
#  4   Ship Mode       51290 non-null  object
#  5   Customer ID     51290 non-null  object
#  6   Customer Name   51290 non-null  object
#  7   Segment         51290 non-null  object
#  8   Postal Code     9994 non-null   float64
#  9   City            51290 non-null  object
#  10  State           51290 non-null  object
#  11  Country         51290 non-null  object
#  12  Region          51290 non-null  object
#  13  Market          51290 non-null  object
#  14  Product ID      51290 non-null  object
#  15  Category        51290 non-null  object
# ...

# %% [markdown]
# # Cleaning Steps

# %% [markdown]
# ## Setting Data Types

# %% [markdown]
# I don't see data types that need to be converted

# %% [markdown]
# ### Dealing with missing data

# %%
df.isna().sum()
# Out:
# Row ID                0
# Order ID              0
# Order Date            0
# Ship Date             0
# Ship Mode             0
# Customer ID           0
# Customer Name         0
# Segment               0
# Postal Code       41296
# City                  0
# State                 0
# Country               0
# Region                0
# Market                0
# Product ID            0
# Category              0
# Sub-Category          0
# Product Name          0
# Sales                 0
# Quantity              0
# Discount              0
# Profit                0
# Shipping Cost         0
# Order Priority        0
# dtype: int64

# %% [markdown]
# I have identified where all the missing data is at based on column. There aren't enough missing data to things that matter to have it removed. Postal code has the most missing due to having deliveries outside of the United States where there is no US postal code.

# %%
df.describe()
# Out:
#             Row ID                     Order Date  \
# count  51290.00000                          51290
# mean   25645.50000  2014-05-11 21:26:49.155780864
# min        1.00000            2012-01-01 00:00:00
# 25%    12823.25000            2013-06-19 00:00:00
# 50%    25645.50000            2014-07-08 00:00:00
# 75%    38467.75000            2015-05-22 00:00:00
# max    51290.00000            2015-12-31 00:00:00
# std    14806.29199                            NaN
#
#                            Ship Date   Postal Code         Sales  \
# count                          51290   9994.000000  51290.000000
# mean   2014-05-15 20:42:42.745174528  55190.379428    246.490581
# min              2012-01-03 00:00:00   1040.000000      0.444000
# 25%              2013-06-23 00:00:00  23223.000000     30.758625
# 50%              2014-07-12 00:00:00  56430.500000     85.053000
# 75%              2015-05-26 00:00:00  90008.000000    251.053200
# ...

# %% [markdown]
# # Cleaning VERSION 2

# %%
df['Postal Code'].sample(20)
# Out:
# 5656         NaN
# 17747    77095.0
# 44001        NaN
# 49443        NaN
# 45751        NaN
# 28325        NaN
# 26983        NaN
# 34003        NaN
# 39620        NaN
# 6798         NaN
# 68           NaN
# 22996    89015.0
# 24001        NaN
# 37525        NaN
# 12748        NaN
# 462          NaN
# 32300        NaN
# 44156        NaN
# 24251        NaN
# 26100        NaN
# Name: Postal Code, dtype: float64

# %%
# Get a count of null values
df.isna()
# Out:
#        Row ID  Order ID  Order Date  Ship Date  Ship Mode  Customer ID  \
# 0       False     False       False      False      False        False
# 1       False     False       False      False      False        False
# 2       False     False       False      False      False        False
# 3       False     False       False      False      False        False
# 4       False     False       False      False      False        False
# ...       ...       ...         ...        ...        ...          ...
# 51285   False     False       False      False      False        False
# 51286   False     False       False      False      False        False
# 51287   False     False       False      False      False        False
# 51288   False     False       False      False      False        False
# 51289   False     False       False      False      False        False
#
#        Customer Name  Segment  Postal Code   City  State  Country  Region  \
# ...

# %%
# Get a count of non null values
df.isna().sum()
# Out:
# Row ID                0
# Order ID              0
# Order Date            0
# Ship Date             0
# Ship Mode             0
# Customer ID           0
# Customer Name         0
# Segment               0
# Postal Code       41296
# City                  0
# State                 0
# Country               0
# Region                0
# Market                0
# Product ID            0
# Category              0
# Sub-Category          0
# Product Name          0
# Sales                 0
# Quantity              0
# Discount              0
# Profit                0
# Shipping Cost         0
# Order Priority        0
# dtype: int64

# %% [markdown]
# # Examine Postal Code Nulls and Data Type

# %%
# Total nulls for Postal Code
df['Postal Code'].isnull().sum()
# Out:
# 41296

# %%
# NON-nulls for Postal Code
df['Postal Code'].notnull().sum()
# Out:
# 9994

# %%
df.head(1)
# Out:
#    Row ID                Order ID Order Date  Ship Date       Ship Mode  \
# 0   42433  AG-2012-TB112803-40909 2012-01-01 2012-01-06  Standard Class
#
#   Customer ID    Customer Name   Segment  Postal Code         City  \
# 0   TB-112803  Toby Braunhardt  Consumer          NaN  Constantine
#
#          State  Country        Region  Market   Product ID         Category  \
# 0  Constantine  Algeria  North Africa  Africa  OFF-ST-6261  Office Supplies
#
#   Sub-Category         Product Name  Sales  Quantity  Discount  Profit  \
# 0      Storage  Tenex Lockers, Blue  408.3         2       0.0  106.14
#
#    Shipping Cost Order Priority
# 0          35.46         Medium

# %%
# View Location columns for records where Postal Code is Null
columns = ['Country', 'State', 'City', 'Postal Code']

mask = df['Postal Code'].isnull()

df[columns].loc[mask].head(10)
# Out:
#        Country            State            City  Postal Code
# 0      Algeria      Constantine     Constantine          NaN
# 1    Australia  New South Wales     Wagga Wagga          NaN
# 2      Hungary         Budapest        Budapest          NaN
# 3       Sweden        Stockholm       Stockholm          NaN
# 4    Australia  New South Wales     Wagga Wagga          NaN
# 5    Australia  New South Wales     Wagga Wagga          NaN
# 6       Canada          Ontario  St. Catharines          NaN
# 7    Australia  New South Wales          Sydney          NaN
# 8  New Zealand         Auckland        Papakura          NaN
# 9         Iraq           Ninawa           Mosul          NaN

# %%
# View location columns for records where postal code is not null
columns = ['Country', 'State', 'City', 'Postal Code']

mask = df['Postal Code'].notnull()

df[columns].loc[mask].sort_values('Country').head(10)
# Out:
#              Country       State         City  Postal Code
# 29     United States       Texas      Houston      77095.0
# 33669  United States  California   Sacramento      95823.0
# 33678  United States    Illinois       Aurora      60505.0
# 33679  United States      Oregon  Springfield      97477.0
# 33681  United States     Florida        Miami      33178.0
# 33682  United States     Florida        Miami      33178.0
# 33685  United States   Tennessee      Bristol      37620.0
# 33686  United States   Tennessee      Bristol      37620.0
# 33690  United States  California  Los Angeles      90045.0
# 33698  United States   Wisconsin    Milwaukee      53209.0

# %%
# Get value_counts where postal code is not null
columns = ['Country', 'State', 'City', 'Postal Code']

mask = df['Postal Code'].notnull()

df[columns].loc[mask].value_counts().head(10)
# Out:
# Country        State         City           Postal Code
# United States  New York      New York City  10035.0        263
#                                             10024.0        230
#                                             10009.0        229
#                California    San Francisco  94122.0        203
#                New York      New York City  10011.0        193
#                California    San Francisco  94110.0        166
#                Washington    Seattle        98105.0        165
#                Pennsylvania  Philadelphia   19134.0        160
#                California    Los Angeles    90049.0        151
#                Washington    Seattle        98103.0        151
# Name: count, dtype: int64

# %%
# Get value_counts where postal code is not null
#Convert to a dataframe and sort by postal code
columns = ['Country', 'State', 'City', 'Postal Code']

mask = df['Postal Code'].notnull()

df[columns].loc[mask].value_counts().to_frame().sort_values('Postal Code').head(10)
# Out:
#                                                      count
# Country       State         City        Postal Code
# United States Massachusetts Holyoke     1040.0           1
#                             Leominster  1453.0           6
#                             Marlborough 1752.0           2
#                             Andover     1810.0           4
#                             Lawrence    1841.0          33
#                             Lowell      1852.0          16
#                             Beverly     1915.0           3
#                             Franklin    2038.0          17
#                             Cambridge   2138.0           6
#                             Malden      2148.0           3

# %%
# Re-read the original data into a new dataframe
# Specify object data type for postal code
df1 = pd.read_excel('/content/drive/MyDrive/Descriptive Analytics/Superstore EDA/Data/Global_Superstore_Orders_2012_2015.xlsx', dtype={'Postal Code': object})
df1.sample(3)
# Out:
#        Row ID                  Order ID Order Date  Ship Date       Ship Mode  \
# 28205   27459   IN-2014-EB1384027-41891 2014-09-09 2014-09-15  Standard Class
# 27504   38999  CA-2014-AA10480140-41878 2014-08-27 2014-09-03  Standard Class
# 41732   47773    MO-2015-EM420086-42218 2015-08-02 2015-08-02        Same Day
#
#         Customer ID  Customer Name      Segment Postal Code      City  \
# 28205    EB-1384027  Ellis Ballard    Corporate         NaN  Neijiang
# 27504  AA-104801402   Andrew Allen     Consumer       48234   Detroit
# 41732     EM-420086  Evan Minnotte  Home Office         NaN      Sale
#
#                          State        Country        Region        Market  \
# 28205                  Sichuan          China  Eastern Asia  Asia Pacific
# 27504                 Michigan  United States    Central US          USCA
# 41732  Rabat-Salé-Zemmour-Zaer        Morocco  North Africa        Africa
#
#         Product ID         Category Sub-Category  \
# ...

# %%
# Making it easier to get to the superstore file by defining the path as path
# creating a new dataframe using path to shorten the code and make it easier to read
path = '/content/drive/MyDrive/Descriptive Analytics/Superstore EDA/Data/Global_Superstore_Orders_2012_2015.xlsx'

df1 = pd.read_excel(path, dtype={'Postal Code': object})
df1.sample(3)
# Out:
#        Row ID                 Order ID Order Date  Ship Date       Ship Mode  \
# 40964   45494  TU-2015-JB6000134-42195 2015-07-10 2015-07-16  Standard Class
# 48777   27900  ID-2015-BP1118559-42333 2015-11-25 2015-11-29  Standard Class
# 26258   45529    MO-2014-AP72086-41849 2014-07-29 2014-08-01    Second Class
#
#       Customer ID Customer Name      Segment Postal Code        City  \
# 40964  JB-6000134     Joy Bell-     Consumer         NaN       Siirt
# 48777  BP-1118559  Ben Peterman    Corporate         NaN   Palembang
# 26258    AP-72086    Anne Pryor  Home Office         NaN  Casablanca
#
#                   State    Country             Region        Market  \
# 40964             Siirt     Turkey       Western Asia  Asia Pacific
# 48777  Sumatera Selatan  Indonesia  Southeastern Asia  Asia Pacific
# 26258  Grand Casablanca    Morocco       North Africa        Africa
#
#         Product ID         Category Sub-Category  \
# 40964  TEC-AC-3403       Technology  Accessories
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51290 entries, 0 to 51289
# Data columns (total 24 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Row ID          51290 non-null  int64
#  1   Order ID        51290 non-null  object
#  2   Order Date      51290 non-null  datetime64[ns]
#  3   Ship Date       51290 non-null  datetime64[ns]
#  4   Ship Mode       51290 non-null  object
#  5   Customer ID     51290 non-null  object
#  6   Customer Name   51290 non-null  object
#  7   Segment         51290 non-null  object
#  8   Postal Code     9994 non-null   object
#  9   City            51290 non-null  object
#  10  State           51290 non-null  object
#  11  Country         51290 non-null  object
#  12  Region          51290 non-null  object
#  13  Market          51290 non-null  object
#  14  Product ID      51290 non-null  object
#  15  Category        51290 non-null  object
# ...

# %%
# viewing the amount of times a postal code occurs in df1
df1['Postal Code'].value_counts()
# Out:
# Postal Code
# 10035    263
# 10024    230
# 10009    229
# 94122    203
# 10011    193
#         ...
# 76248      1
# 32174      1
# 32503      1
# 77536      1
# 98208      1
# Name: count, Length: 631, dtype: int64

# %%
# convert postal code into a string to keep the leading 0
df1['Postal Code'] = df1['Postal Code'].astype(str)
df1['Postal Code'].sort_values()
# Out:
# 22218    05408
# 34290    05408
# 17508    05408
# 34289    05408
# 49612    05408
#          ...
# 19154      nan
# 19155      nan
# 19157      nan
# 19131      nan
# 51289      nan
# Name: Postal Code, Length: 51290, dtype: object

# %%
# define a list of columns
columns = ['Country', 'State', 'City', 'Postal Code']
# create mask to filter row where state = Massachusetts
mask = df1['State'] == 'Massachusetts'
# filter df1 using mask
# sort the rows by postal code in ascending order
df1[columns].loc[mask].sort_values('Postal Code').head(3)
# Out:
#              Country          State        City Postal Code
# 13405  United States  Massachusetts     Holyoke        1040
# 18442  United States  Massachusetts  Leominster        1453
# 9923   United States  Massachusetts  Leominster        1453

# %%
# convert postal code into a string and add 0s to the front if needed to make sure its 5 characters
df1['Postal Code'] = df1['Postal Code'].astype('str').str.zfill(5)
# define list of columns shown
columns = ['Country', 'State', 'City', 'Postal Code']
# create mask to filter where state = Massechuessetts
mask = df1['State'] == 'Massachusetts'
# filter the df using mask and selected columns then sorting by postal codie in ascending order
df1[columns].loc[mask].sort_values('Postal Code').head(3)
# Out:
#              Country          State        City Postal Code
# 13405  United States  Massachusetts     Holyoke       01040
# 18442  United States  Massachusetts  Leominster       01453
# 9923   United States  Massachusetts  Leominster       01453

# %%
df1['Postal Code'].sample(3)
# Out:
# 38486    00nan
# 3011     00nan
# 16015    00nan
# Name: Postal Code, dtype: object

# %%
# replace all '00nan' with 'na' in postal code
df1['Postal Code'].replace('00nan', 'na', inplace=True)
df1['Postal Code'].sample(3)
# Out:
# <ipython-input-35-0f26769ab29d>:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df1['Postal Code'].replace('00nan', 'na', inplace=True)
# 20516       na
# 47021    43229
# 15767       na
# Name: Postal Code, dtype: object

# %%
# counts frequency of each unique postal code
df1['Postal Code'].value_counts().sort_index()
# Out:
# Postal Code
# 01040        1
# 01453        6
# 01752        2
# 01810        4
# 01841       33
#          ...
# 98632        3
# 98661        5
# 99207        7
# 99301        6
# na       41296
# Name: count, Length: 632, dtype: int64

# %%
path = '/content/drive/MyDrive/Descriptive Analytics/Superstore EDA/Data/Global_Superstore_Orders_2012_2015.xlsx'
df = pd.read_excel(path, dtype={'Postal Code': object})
df['Postal Code'] = df['Postal Code'].astype(str).str.zfill(5)
df['Postal Code'].replace('00nan', 'na', inplace=True)
# Out:
# <ipython-input-37-24ebe7f52da3>:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Postal Code'].replace('00nan', 'na', inplace=True)

# %%
path = '/content/drive/MyDrive/Descriptive Analytics/Superstore EDA/Data/Global_Superstore_Orders_2012_2015.xlsx'
df = pd.read_excel(path, dtype={'Postal Code': str})
df['Postal Code'] = df['Postal Code'].str.zfill(5).fillna('na')

columns = ['Country', 'State', 'City', 'Postal Code']
df.sample(15)
# Out:
#        Row ID                  Order ID Order Date  Ship Date       Ship Mode  \
# 27394   45495    LY-2014-JE616574-41874 2014-08-23 2014-08-28    Second Class
# 18384   32844  CA-2013-VB21745140-41601 2013-11-23 2013-11-27  Standard Class
# 791     28380   IN-2012-LC1687027-40965 2012-02-26 2012-03-01  Standard Class
# 12263   40125  CA-2013-BB11545140-41430 2013-06-05 2013-06-09  Standard Class
# 5840    33572  CA-2012-AR10405140-41184 2012-10-02 2012-10-07    Second Class
# 47372   22958    ID-2015-LR170357-42315 2015-11-07 2015-11-13  Standard Class
# 38638   14881    ES-2015-KD164958-42151 2015-05-27 2015-06-02  Standard Class
# 50250   19462  IT-2015-MS17530139-42354 2015-12-16 2015-12-21  Standard Class
# 15153   33057  CA-2013-AG10900140-41522 2013-09-05 2013-09-09  Standard Class
# 15363    1660   US-2013-KB1660055-41527 2013-09-10 2013-09-14  Standard Class
# 33194    1553   MX-2014-AA1064582-41993 2014-12-20 2014-12-22     First Class
# ...

# %% [markdown]
# # Visualization

# %% [markdown]
# ## Histograms

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.histplot(df['Sales'], binwidth=100);
plt.xlim(0,5000)
# Out:
# (0.0, 5000.0)

# %% [markdown]
# Each band houses 100 values. A lot of these items are not bringing in much in sales.

# %%
sns.histplot(df['Quantity']);

# %% [markdown]
# This shows how often an item shows up in the df.

# %%
sns.histplot(df['Discount']);

# %% [markdown]
# This shows how often a certain discount happens.

# %%
sns.histplot(df['Profit'], binwidth=100);
plt.xlim(-2000,2000)
# Out:
# (-2000.0, 2000.0)

# %% [markdown]
# Each bin consists of 100 values. This histogram shows profit.

# %%
sns.histplot(df['Shipping Cost'], binwidth=20);
plt.xlim(0,500)
# Out:
# (0.0, 500.0)

# %% [markdown]
# This shows how often a shipping cost happens.

# %% [markdown]
# ## Boxplots

# %%
sns.boxplot(x=df.Sales);

# %% [markdown]
# Most of the items sell for much closer to 0 and there are a lot of outliers.

# %%
sns.boxplot(x=df.Quantity);

# %% [markdown]
# The majority of the items have a sales quantity between 2-4

# %%
sns.boxplot(x=df.Discount);

# %% [markdown]
# The majority of the discounts given on the items are between 0 and 20%

# %%
sns.boxplot(x=df.Profit);

# %% [markdown]
# Most of the profit per specific item is around 0. There are a lot of outliers, both postive and negative.

# %%
sns.boxplot(x=df['Shipping Cost']);

# %% [markdown]
# There are many outliers found in the shipping cost.

# %% [markdown]
# ## Bar Charts

# %%
data = df['Ship Mode'].value_counts()
data.plot.barh();

# %%
data = df['Ship Mode'].value_counts()
data.plot.bar();

# %% [markdown]
# Shows the amount of items that were shipped with each class of transportation

# %%
data = df['Segment'].value_counts()
data.plot.barh();

# %%
data = df['Segment'].value_counts()
data.plot.bar();

# %% [markdown]
# Shows the amount of items that are shipped to what segment

# %%
data = df['Region'].value_counts()
data.plot.barh();

# %%
data = df['Region'].value_counts()
data.plot.bar();

# %% [markdown]
# Shows where in the world items were sent to

# %%
data = df['Market'].value_counts()
data.plot.barh();

# %%
data = df['Market'].value_counts()
data.plot.bar();

# %% [markdown]
# Shows where in the world items were shipped to

# %%
data = df['Category'].value_counts()
data.plot.barh();

# %%
data = df['Category'].value_counts()
data.plot.bar();

# %% [markdown]
# A break down of the amount of each category of item that was purchased

# %%
data = df['Sub-Category'].value_counts()
data.plot.barh();

# %%
data = df['Sub-Category'].value_counts()
data.plot.bar();

# %% [markdown]
# A further breakdown of which items were ordered

# %%
data = df['Order Priority'].value_counts()
data.plot.barh();

# %%
data = df['Order Priority'].value_counts()
data.plot.bar();

# %% [markdown]
# Shows the number of times an item was shipped with what kind of priority

# %%
# Sales
df['Sales'].describe()
# Out:
# count    51290.000000
# mean       246.490581
# std        487.565361
# min          0.444000
# 25%         30.758625
# 50%         85.053000
# 75%        251.053200
# max      22638.480000
# Name: Sales, dtype: float64

# %%
# Total sales by segment
df.groupby('Segment')['Sales'].sum()
# Out:
# Segment
# Consumer       6.507949e+06
# Corporate      3.824698e+06
# Home Office    2.309855e+06
# Name: Sales, dtype: float64

# %%
# prompt: set pandas to display numbers without scientific notation

pd.set_option('display.float_format', '{:,.2f}'.format)

# %%
# Total sales by segment bar chart
data = df.groupby('Segment')['Sales'].sum()
data.plot.bar();

# %%
# Total sales by segment bar chart
data = df.groupby('Segment')['Sales'].sum().sort_values()
data.plot.barh();

# %%
# Total sales by category bar chart
rawdata = df.groupby('Category')['Sales'].sum().sort_values(ascending=False)
print(rawdata)
data = df.groupby('Category')['Sales'].sum().sort_values()
data.plot.barh();
# Out:
# Category
# Technology        4,744,557.50
# Furniture         4,110,451.90
# Office Supplies   3,787,492.51
# Name: Sales, dtype: float64

# %%
# Total sales by sub-category bar chart
rawdata = df.groupby('Sub-Category')['Sales'].sum().sort_values(ascending=False)
print(rawdata)
data = df.groupby('Sub-Category')['Sales'].sum().sort_values()
data.plot.barh();
# Out:
# Sub-Category
# Phones        1,706,824.14
# Copiers       1,509,436.27
# Chairs        1,501,681.76
# Bookcases     1,466,572.24
# Storage       1,126,812.97
# Appliances    1,010,535.53
# Machines        779,060.07
# Tables          757,041.92
# Accessories     749,237.02
# Binders         461,869.39
# Furnishings     385,155.97
# Art             371,613.15
# Supplies        242,811.13
# Paper           241,787.53
# Envelopes       169,217.49
# Fasteners        89,495.05
# Labels           73,350.28
# Name: Sales, dtype: float64

# %%
# Total sales by segment bar chart
rawdata = df.groupby('Segment')['Sales'].sum().sort_values(ascending=False)
print(rawdata)
data = df.groupby('Segment')['Sales'].sum().sort_values()
data.plot.barh();
# Out:
# Segment
# Consumer      6,507,949.42
# Corporate     3,824,697.52
# Home Office   2,309,854.97
# Name: Sales, dtype: float64

# %%
# Total sales by market bar chart
rawdata = df.groupby('Market')['Sales'].sum().sort_values(ascending=False)
print(rawdata)
data = df.groupby('Market')['Sales'].sum().sort_values()
data.plot.barh();
# Out:
# Market
# Asia Pacific   4,042,658.27
# Europe         3,287,336.23
# USCA           2,364,129.03
# LATAM          2,164,605.17
# Africa           783,773.21
# Name: Sales, dtype: float64

# %%
# Total sales by region bar chart
rawdata = df.groupby('Region')['Sales'].sum().sort_values(ascending=False)
print(rawdata)
data = df.groupby('Region')['Sales'].sum().sort_values()
data.plot.barh();
# Out:
# Region
# Western Europe      1,731,929.67
# Central America     1,223,100.63
# Oceania             1,100,184.61
# Southeastern Asia     884,423.17
# Southern Asia         866,572.68
# Eastern Asia          855,059.39
# Western US            725,457.82
# Eastern US            678,781.24
# Northern Europe       636,779.16
# South America         617,223.68
# Southern Europe       608,593.97
# Central US            501,239.89
# Southern US           391,721.91
# Caribbean             324,280.86
# Western Asia          317,106.96
# Eastern Europe        310,033.44
# North Africa          233,216.61
# Western Africa        173,878.81
# Central Africa        143,630.01
# Eastern Africa        127,856.02
# Southern Africa       105,191.76
# Canada                 66,928.17
# Central Asia           19,311.46
# Name: Sales, dtype: float64

# %% [markdown]
# # Time Series Dates

# %%
# Group sales data by year and month
# creates new dataframe: monthly sales
monthly_sales = df.groupby([df['Order Date'].dt.to_period('M')])['Sales'].sum().reset_index()
monthly_sales.head()
# Out:
#   Order Date      Sales
# 0    2012-01  98,898.49
# 1    2012-02 103,717.92
# 2    2012-03 135,746.40
# 3    2012-04 114,332.96
# 4    2012-05 158,228.33

# %%
monthly_sales
# Out:
#    Order Date      Sales
# 0     2012-01  98,898.49
# 1     2012-02 103,717.92
# 2     2012-03 135,746.40
# 3     2012-04 114,332.96
# 4     2012-05 158,228.33
# 5     2012-06 207,571.54
# 6     2012-07 118,434.88
# 7     2012-08 208,063.28
# 8     2012-09 284,587.75
# 9     2012-10 216,114.57
# 10    2012-11 293,947.35
# 11    2012-12 319,807.41
# 12    2013-01 137,435.98
# 13    2013-02  98,854.96
# 14    2013-03 163,076.77
# 15    2013-04 161,052.27
# 16    2013-05 208,364.89
# 17    2013-06 256,175.70
# 18    2013-07 145,236.79
# 19    2013-08 303,142.94
# 20    2013-09 289,389.17
# 21    2013-10 252,939.85
# 22    2013-11 323,512.42
# 23    2013-12 338,256.97
# 24    2014-01 199,185.91
# 25    2014-02 167,239.65
# 26    2014-03 198,594.03
# 27    2014-04 177,821.32
# 28    2014-05 260,498.56
# 29    2014-06 396,519.61
# 30    2014-07 229,928.95
# 31    2014-08 326,488.79
# 32    2014-09 376,619.25
# 33    2014-10 293,406.64
# 34    2014-11 373,989.36
# 35    2014-12 405,454.38
# ...

# %% [markdown]
# ## Part 2

# %%
monthly_sales['Order Date'] = monthly_sales['Order Date'].astype(str)

plt.figure(figsize=(12,6))
plt.plot(monthly_sales['Order Date'], monthly_sales['Sales'])
plt.title('Sales by Month', fontsize=14)
plt.xlabel('Month', fontsize=12)
plt.ylabel('Total Sales', fontsize=12)
plt.xticks(rotation=90)
plt.grid(axis='y', linestyle='-', linewidth=0.5, alpha=0.6)

plt.show()

# %% [markdown]
# This shows monthly sales by the date the order was placed

# %% [markdown]
# ## Part 3

# %%
quarterly_sales = df.groupby([df['Order Date'].dt.to_period('Q')])['Sales'].sum().reset_index()
quarterly_sales['Order Date'] = quarterly_sales['Order Date'].astype(str).str.replace('Q', '-Q')
quarterly_sales.head(10)
# Out:
#   Order Date      Sales
# 0    2012-Q1 338,362.81
# 1    2012-Q2 480,132.84
# 2    2012-Q3 611,085.92
# 3    2012-Q4 829,869.33
# 4    2013-Q1 399,367.71
# 5    2013-Q2 625,592.86
# 6    2013-Q3 737,768.89
# 7    2013-Q4 914,709.23
# 8    2014-Q1 565,019.59
# 9    2014-Q2 834,839.49

# %%
plt.figure(figsize=(12,6))
plt.plot(quarterly_sales['Order Date'], quarterly_sales['Sales'])
plt.title('Sales by Quarter', fontsize=14)
plt.xlabel('Quarter', fontsize=12)
plt.ylabel('Total Sales', fontsize=12)
plt.xticks(rotation=90)
plt.grid(axis='y', linestyle='-', linewidth=0.5, alpha=0.6)

plt.show()

# %% [markdown]
# This shows quarterly sales by the date the order was placed

# %% [markdown]
# ## Part 4

# %%
# resample the df to change to be at the end of the month
monthly_sales_rs = df.resample('ME', on='Order Date')['Sales'].sum().reset_index()

# %%
monthly_sales_rs.head(30)
# Out:
#    Order Date      Sales
# 0  2012-01-31  98,898.49
# 1  2012-02-29 103,717.92
# 2  2012-03-31 135,746.40
# 3  2012-04-30 114,332.96
# 4  2012-05-31 158,228.33
# 5  2012-06-30 207,571.54
# 6  2012-07-31 118,434.88
# 7  2012-08-31 208,063.28
# 8  2012-09-30 284,587.75
# 9  2012-10-31 216,114.57
# 10 2012-11-30 293,947.35
# 11 2012-12-31 319,807.41
# 12 2013-01-31 137,435.98
# 13 2013-02-28  98,854.96
# 14 2013-03-31 163,076.77
# 15 2013-04-30 161,052.27
# 16 2013-05-31 208,364.89
# 17 2013-06-30 256,175.70
# 18 2013-07-31 145,236.79
# 19 2013-08-31 303,142.94
# 20 2013-09-30 289,389.17
# 21 2013-10-31 252,939.85
# 22 2013-11-30 323,512.42
# 23 2013-12-31 338,256.97
# 24 2014-01-31 199,185.91
# 25 2014-02-28 167,239.65
# 26 2014-03-31 198,594.03
# 27 2014-04-30 177,821.32
# 28 2014-05-31 260,498.56
# 29 2014-06-30 396,519.61

# %%
monthly_sales_rs['Order Date'] = monthly_sales_rs['Order Date'].astype(str)

plt.figure(figsize=(12,6))
plt.plot(monthly_sales_rs['Order Date'], monthly_sales_rs['Sales'])
plt.title('Sales by Month', fontsize=14)
plt.xlabel('Month', fontsize=12)
plt.ylabel('Total Sales', fontsize=12)
plt.xticks(rotation=90)
plt.grid(axis='y', linestyle='-', linewidth=0.5, alpha=0.6)

plt.show()

# %% [markdown]
# This shows monthly sales by the date the order was placed as of the end of the month

# %% [markdown]
# ## Part 5

# %%
quarterly_sales_rs = df.resample('QE', on='Order Date')['Sales'].sum().reset_index()
quarterly_sales_rs
# Out:
#    Order Date        Sales
# 0  2012-03-31   338,362.81
# 1  2012-06-30   480,132.84
# 2  2012-09-30   611,085.92
# 3  2012-12-31   829,869.33
# 4  2013-03-31   399,367.71
# 5  2013-06-30   625,592.86
# 6  2013-09-30   737,768.89
# 7  2013-12-31   914,709.23
# 8  2014-03-31   565,019.59
# 9  2014-06-30   834,839.49
# 10 2014-09-30   933,036.99
# 11 2014-12-31 1,072,850.38
# 12 2015-03-31   689,206.68
# 13 2015-06-30   932,986.97
# 14 2015-09-30 1,196,482.87
# 15 2015-12-31 1,481,189.35
