# %% [markdown]
# # Olympics Merge
# Ryan Morrissey

# %% [markdown]
# ### Dictionary
# df = path for cvs file for Olympics data
#
# df_noc = path for cvs file for Olympics data to show the region olympians were from

# %%
import pandas as pd

# %%
# path to access olympic data for athletes as cvs file

df = pd.read_csv('/content/drive/MyDrive/Descriptive Analytics/Olympics EDA/Data/athlete_events.csv')

# %%
df.head()
# Out:
#    ID                      Name Sex   Age  Height  Weight            Team  \
# 0   1                 A Dijiang   M  24.0   180.0    80.0           China
# 1   2                  A Lamusi   M  23.0   170.0    60.0           China
# 2   3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN         Denmark
# 3   4      Edgar Lindenau Aabye   M  34.0     NaN     NaN  Denmark/Sweden
# 4   5  Christine Jacoba Aaftink   F  21.0   185.0    82.0     Netherlands
#
#    NOC        Games  Year  Season       City          Sport  \
# 0  CHN  1992 Summer  1992  Summer  Barcelona     Basketball
# 1  CHN  2012 Summer  2012  Summer     London           Judo
# 2  DEN  1920 Summer  1920  Summer  Antwerpen       Football
# 3  DEN  1900 Summer  1900  Summer      Paris     Tug-Of-War
# 4  NED  1988 Winter  1988  Winter    Calgary  Speed Skating
#
#                               Event Medal
# 0       Basketball Men's Basketball   NaN
# 1      Judo Men's Extra-Lightweight   NaN
# ...

# %%
df.tail()
# Out:
#             ID                Name Sex   Age  Height  Weight      Team  NOC  \
# 271111  135569          Andrzej ya   M  29.0   179.0    89.0  Poland-1  POL
# 271112  135570            Piotr ya   M  27.0   176.0    59.0    Poland  POL
# 271113  135570            Piotr ya   M  27.0   176.0    59.0    Poland  POL
# 271114  135571  Tomasz Ireneusz ya   M  30.0   185.0    96.0    Poland  POL
# 271115  135571  Tomasz Ireneusz ya   M  34.0   185.0    96.0    Poland  POL
#
#               Games  Year  Season            City        Sport  \
# 271111  1976 Winter  1976  Winter       Innsbruck         Luge
# 271112  2014 Winter  2014  Winter           Sochi  Ski Jumping
# 271113  2014 Winter  2014  Winter           Sochi  Ski Jumping
# 271114  1998 Winter  1998  Winter          Nagano    Bobsleigh
# 271115  2002 Winter  2002  Winter  Salt Lake City    Bobsleigh
#
#                                            Event Medal
# 271111                Luge Mixed (Men)'s Doubles   NaN
# ...

# %%
df.sample(24)
# Out:
#             ID                                               Name Sex   Age  \
# 26522    13807                               Konstantinos Botasis   M   NaN
# 117234   59369         Yekaterina Vladimirovna Khomyakova-Birlova   F  24.0
# 221067  111076                                 Jagmal Singh Ragho   M  37.0
# 139478   70049          Gerola Margareta Lindahl (-Sturzenbecker)   F  21.0
# 181003   90975                      Kristina Dimitrova Panayotova   F  16.0
# 62899    32242                                          Jzsef les   M  23.0
# 25680    13413                                        Jzsef Bords   M  25.0
# 182392   91689               Aleksandr Aleksandrovich Parkhomenko   M  23.0
# 29955    15458                                       Yves Brouzet   M  23.0
# 190289   95579                                         Dnes Pcsik   M  24.0
# 156338   78512  Hanna Anatolivna Melnychenko-Kasianova (-Frull...   F  33.0
# ...

# %%
df.shape
# Out:
# (271116, 15)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 271116 entries, 0 to 271115
# Data columns (total 15 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   ID      271116 non-null  int64
#  1   Name    271116 non-null  object
#  2   Sex     271116 non-null  object
#  3   Age     261642 non-null  float64
#  4   Height  210945 non-null  float64
#  5   Weight  208241 non-null  float64
#  6   Team    271116 non-null  object
#  7   NOC     271116 non-null  object
#  8   Games   271116 non-null  object
#  9   Year    271116 non-null  int64
#  10  Season  271116 non-null  object
#  11  City    271116 non-null  object
#  12  Sport   271116 non-null  object
#  13  Event   271116 non-null  object
#  14  Medal   39783 non-null   object
# dtypes: float64(3), int64(2), object(10)
# memory usage: 31.0+ MB

# %%
df.describe()
# Out:
#                   ID            Age         Height         Weight  \
# count  271116.000000  261642.000000  210945.000000  208241.000000
# mean    68248.954396      25.556898     175.338970      70.702393
# std     39022.286345       6.393561      10.518462      14.348020
# min         1.000000      10.000000     127.000000      25.000000
# 25%     34643.000000      21.000000     168.000000      60.000000
# 50%     68205.000000      24.000000     175.000000      70.000000
# 75%    102097.250000      28.000000     183.000000      79.000000
# max    135571.000000      97.000000     226.000000     214.000000
#
#                 Year
# count  271116.000000
# mean     1978.378480
# std        29.877632
# min      1896.000000
# 25%      1960.000000
# 50%      1988.000000
# 75%      2002.000000
# max      2016.000000

# %% [markdown]
# ## Questions
#
# ### Age
# what athletes were in thier 90s? From what sports, events, countryn year?

# %% [markdown]
# ### Get description of non-numeric fields

# %%
# Get a description of the object fields
df.describe(include='object')
# Out:
#                         Name     Sex           Team     NOC        Games  \
# count                 271116  271116         271116  271116       271116
# unique                134732       2           1184     230           51
# top     Robert Tait McKenzie       M  United States     USA  2000 Summer
# freq                      58  196594          17847   18853        13821
#
#         Season    City      Sport                    Event  Medal
# count   271116  271116     271116                   271116  39783
# unique       2      42         66                      765      3
# top     Summer  London  Athletics  Football Men's Football   Gold
# freq    222552   22426      38624                     5733  13372

# %% [markdown]
# ## Merge Files: 'athlete_events' with 'noc_regions'

# %%
# Read the noc_regions.csv file
# store to df_noc

df_noc = pd.read_csv('/content/drive/MyDrive/Descriptive Analytics/Olympics EDA/Data/noc_regions.csv')
df_noc.head()
# Out:
#    NOC       region                 notes
# 0  AFG  Afghanistan                   NaN
# 1  AHO      Curacao  Netherlands Antilles
# 2  ALB      Albania                   NaN
# 3  ALG      Algeria                   NaN
# 4  AND      Andorra                   NaN

# %%
df_noc.shape
# Out:
# (230, 3)

# %%
df_noc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 230 entries, 0 to 229
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   NOC     230 non-null    object
#  1   region  227 non-null    object
#  2   notes   21 non-null     object
# dtypes: object(3)
# memory usage: 5.5+ KB

# %%
# prompt: View the records from df_noc which have non-null values for notes

# Display records with non-null values in the 'notes' column of df_noc
print(df_noc[df_noc['notes'].notnull()])
# Out:
#      NOC                       region                        notes
# 1    AHO                      Curacao         Netherlands Antilles
# 6    ANT                      Antigua          Antigua and Barbuda
# 7    ANZ                    Australia                  Australasia
# 26   BOH               Czech Republic                      Bohemia
# 51   CRT                       Greece                        Crete
# 88   HKG                        China                    Hong Kong
# 93   IOA  Individual Olympic Athletes  Individual Olympic Athletes
# 99   ISV           Virgin Islands, US               Virgin Islands
# 143  NBO                     Malaysia                 North Borneo
# 147  NFL                       Canada                 Newfoundland
# 168  ROT                          NaN         Refugee Olympic Team
# 175  SCG                       Serbia        Serbia and Montenegro
# 179  SKN                  Saint Kitts     Turks and Caicos Islands
# ...

# %%
# Megre df with df_noc
df = df.merge(df_noc, how="left", on="NOC")
df.sample(20)
# Out:
#             ID                        Name Sex   Age  Height  Weight  \
# 137882   69300           Patrice Lhtellier   M  22.0   176.0    63.0
# 140081   70332           Christopher Linke   M  27.0   191.0    66.0
# 76307    38721        John Garcia-Thompson   M  33.0   192.0    92.0
# 134010   67475                   Le Jingyi   F  21.0   178.0    68.0
# 124557   62905         Lisbeth Korsmo-Berg   F  20.0   160.0    56.0
# 205478  103164      Simone Ruas (-Peirone)   F  29.0     NaN     NaN
# 33413    17231       Raymond "Ray" Cadieux   M  22.0   178.0    77.0
# 66849    34192        Hans-Joachim Fanacht   M  21.0   175.0    70.0
# 143946   72249  Eva Maria Lund (-Eriksson)   F  38.0   169.0    66.0
# 221818  111490                 akir xliyev   M  21.0   163.0     NaN
# 44947    23180              Heather Corrie   F  37.0   173.0    59.0
# 168918   84899        Samson N'Dicka-Matam   M  24.0   164.0    63.0
# 145499   73023         Thomas P. Mack, Jr.   M  18.0   147.0    41.0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 271116 entries, 0 to 271115
# Data columns (total 17 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   ID      271116 non-null  int64
#  1   Name    271116 non-null  object
#  2   Sex     271116 non-null  object
#  3   Age     261642 non-null  float64
#  4   Height  210945 non-null  float64
#  5   Weight  208241 non-null  float64
#  6   Team    271116 non-null  object
#  7   NOC     271116 non-null  object
#  8   Games   271116 non-null  object
#  9   Year    271116 non-null  int64
#  10  Season  271116 non-null  object
#  11  City    271116 non-null  object
#  12  Sport   271116 non-null  object
#  13  Event   271116 non-null  object
#  14  Medal   39783 non-null   object
#  15  region  270746 non-null  object
#  16  notes   5039 non-null    object
# dtypes: float64(3), int64(2), object(12)
# memory usage: 35.2+ MB

# %%
# show all columns with object data type

df.describe(include='object')
# Out:
#                         Name     Sex           Team     NOC        Games  \
# count                 271116  271116         271116  271116       271116
# unique                134732       2           1184     230           51
# top     Robert Tait McKenzie       M  United States     USA  2000 Summer
# freq                      58  196594          17847   18853        13821
#
#         Season    City      Sport                    Event  Medal  region  \
# count   271116  271116     271116                   271116  39783  270746
# unique       2      42         66                      765      3     205
# top     Summer  London  Athletics  Football Men's Football   Gold     USA
# freq    222552   22426      38624                     5733  13372   18853
#
#              notes
# count         5039
# unique          21
# top     Yugoslavia
# freq          2583

# %% [markdown]
# # Cleaning Steps

# %% [markdown]
# ## Setting Data Types

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 271116 entries, 0 to 271115
# Data columns (total 17 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   ID      271116 non-null  int64
#  1   Name    271116 non-null  object
#  2   Sex     271116 non-null  object
#  3   Age     261642 non-null  float64
#  4   Height  210945 non-null  float64
#  5   Weight  208241 non-null  float64
#  6   Team    271116 non-null  object
#  7   NOC     271116 non-null  object
#  8   Games   271116 non-null  object
#  9   Year    271116 non-null  int64
#  10  Season  271116 non-null  object
#  11  City    271116 non-null  object
#  12  Sport   271116 non-null  object
#  13  Event   271116 non-null  object
#  14  Medal   39783 non-null   object
#  15  region  270746 non-null  object
#  16  notes   5039 non-null    object
# dtypes: float64(3), int64(2), object(12)
# memory usage: 35.2+ MB

# %%
df.sample(5)
# Out:
#             ID                   Name Sex   Age  Height  Weight  \
# 12146     6606    Paul Albert Backman   M  27.0   176.0    67.5
# 202323  101620  Myron Willis Roderick   M  22.0   166.0    62.0
# 235460  118054       Kensuke Takezawa   M  21.0   170.0    53.0
# 138355   69504                 Li Wei   M  18.0     NaN     NaN
# 24643    12905            Nataa Bokal   F  30.0   172.0    68.0
#
#                  Team  NOC        Games  Year  Season       City  \
# 12146         Finland  FIN  1948 Summer  1948  Summer     London
# 202323  United States  USA  1956 Summer  1956  Summer  Melbourne
# 235460          Japan  JPN  2008 Summer  2008  Summer    Beijing
# 138355          China  CHN  1988 Winter  1988  Winter    Calgary
# 24643        Slovenia  SLO  1998 Winter  1998  Winter     Nagano
#
#                  Sport                                     Event Medal  \
# 12146          Cycling       Cycling Men's Road Race, Individual   NaN
# ...

# %% [markdown]
# I don't see any data types that would require conversions. Unless you are trying to find the total number of male and female athletes. You could convert those to intigers and sum, but we can already find this information in df.describe include object.

# %% [markdown]
# # Missing Data

# %%
df.isna().sum()
# Out:
# ID             0
# Name           0
# Sex            0
# Age         9474
# Height     60171
# Weight     62875
# Team           0
# NOC            0
# Games          0
# Year           0
# Season         0
# City           0
# Sport          0
# Event          0
# Medal     231333
# region       370
# notes     266077
# dtype: int64

# %%
# I am removing all athletes that have a Nan value for all of Age, Height, and Weight
# mainly because I am bored and want to see how well it works

df = df.dropna(subset=["Age", "Height", "Weight"])

# %% [markdown]
# This has taken it from 271,116 rows to now 206,165 rows

# %%
df.head()
# Out:
#    ID                      Name Sex   Age  Height  Weight         Team  NOC  \
# 0   1                 A Dijiang   M  24.0   180.0    80.0        China  CHN
# 1   2                  A Lamusi   M  23.0   170.0    60.0        China  CHN
# 4   5  Christine Jacoba Aaftink   F  21.0   185.0    82.0  Netherlands  NED
# 5   5  Christine Jacoba Aaftink   F  21.0   185.0    82.0  Netherlands  NED
# 6   5  Christine Jacoba Aaftink   F  25.0   185.0    82.0  Netherlands  NED
#
#          Games  Year  Season         City          Sport  \
# 0  1992 Summer  1992  Summer    Barcelona     Basketball
# 1  2012 Summer  2012  Summer       London           Judo
# 4  1988 Winter  1988  Winter      Calgary  Speed Skating
# 5  1988 Winter  1988  Winter      Calgary  Speed Skating
# 6  1992 Winter  1992  Winter  Albertville  Speed Skating
#
#                                 Event Medal       region notes
# 0         Basketball Men's Basketball   NaN        China   NaN
# ...

# %%
df.tail()
# Out:
#             ID                Name Sex   Age  Height  Weight      Team  NOC  \
# 271111  135569          Andrzej ya   M  29.0   179.0    89.0  Poland-1  POL
# 271112  135570            Piotr ya   M  27.0   176.0    59.0    Poland  POL
# 271113  135570            Piotr ya   M  27.0   176.0    59.0    Poland  POL
# 271114  135571  Tomasz Ireneusz ya   M  30.0   185.0    96.0    Poland  POL
# 271115  135571  Tomasz Ireneusz ya   M  34.0   185.0    96.0    Poland  POL
#
#               Games  Year  Season            City        Sport  \
# 271111  1976 Winter  1976  Winter       Innsbruck         Luge
# 271112  2014 Winter  2014  Winter           Sochi  Ski Jumping
# 271113  2014 Winter  2014  Winter           Sochi  Ski Jumping
# 271114  1998 Winter  1998  Winter          Nagano    Bobsleigh
# 271115  2002 Winter  2002  Winter  Salt Lake City    Bobsleigh
#
#                                            Event Medal  region notes
# ...

# %%
df.sample(10)
# Out:
#             ID                                 Name Sex   Age  Height  Weight  \
# 26047    13589               Kathrin Boron (-Kppen)   F  38.0   184.0    77.0
# 146430   73483                Themistoklis Magoulas   M  37.0   170.0    69.0
# 243516  121956                       Umberto Trippa   M  25.0   172.0    62.0
# 59434    30447                        Frdric Dufour   M  28.0   178.0    71.0
# 254341  127338                   Patrick von Gunten   M  25.0   180.0    83.0
# 184055   92507     Christie Patricia Pearce-Rampone   F  33.0   168.0    64.0
# 110895   56103             Annette Moldrup Jrgensen   F  22.0   165.0    56.0
# 171387   86128                  Anibl Nieves Javier   M  30.0   168.0    62.0
# 116928   59202                      Houssine Kharja   M  29.0   181.0    77.0
# 22919    12054  Bonnie Kathleen Blair (-Cruikshank)   F  23.0   165.0    59.0
#
#                  Team  NOC        Games  Year  Season       City  \
# ...

# %%
df.shape
# Out:
# (206165, 17)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 206165 entries, 0 to 271115
# Data columns (total 17 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   ID      206165 non-null  int64
#  1   Name    206165 non-null  object
#  2   Sex     206165 non-null  object
#  3   Age     206165 non-null  float64
#  4   Height  206165 non-null  float64
#  5   Weight  206165 non-null  float64
#  6   Team    206165 non-null  object
#  7   NOC     206165 non-null  object
#  8   Games   206165 non-null  object
#  9   Year    206165 non-null  int64
#  10  Season  206165 non-null  object
#  11  City    206165 non-null  object
#  12  Sport   206165 non-null  object
#  13  Event   206165 non-null  object
#  14  Medal   30181 non-null   object
#  15  region  205895 non-null  object
#  16  notes   3493 non-null    object
# dtypes: float64(3), int64(2), object(12)
# memory usage: 28.3+ MB

# %%
df.describe()
# Out:
#                   ID            Age         Height         Weight  \
# count  206165.000000  206165.000000  206165.000000  206165.000000
# mean    68616.017675      25.055509     175.371950      70.688337
# std     38996.514355       5.483096      10.546088      14.340338
# min         1.000000      11.000000     127.000000      25.000000
# 25%     35194.000000      21.000000     168.000000      60.000000
# 50%     68629.000000      24.000000     175.000000      70.000000
# 75%    102313.000000      28.000000     183.000000      79.000000
# max    135571.000000      71.000000     226.000000     214.000000
#
#                 Year
# count  206165.000000
# mean     1989.674678
# std        20.130865
# min      1896.000000
# 25%      1976.000000
# 50%      1992.000000
# 75%      2006.000000
# max      2016.000000

# %% [markdown]
# # Histograms

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # Breakdown of physical attributes of the athletes

# %%
# Histogram of most common weights of athletes
sns.histplot(df['Weight'])
# Out:
# <Axes: xlabel='Weight', ylabel='Count'>

# %%
# Histogram of most common heights of athletes
sns.histplot(df['Age'])
# Out:
# <Axes: xlabel='Age', ylabel='Count'>

# %%
# Histogram of most common heights of athletes
sns.histplot(df['Height'])
# Out:
# <Axes: xlabel='Height', ylabel='Count'>
